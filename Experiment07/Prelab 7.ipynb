# %% [markdown]
# # Prelab 7

# %% [markdown]
# > Create a Jupyter Notebook with your image dropped into a markdown cell, and add some notes about the qualitative behaviour of the output. These notes will help you be efficient in the lab, and know roughly what to expect. Save a .html file of your Jupyter Notebook and upload it here.

# %% [markdown]
# This was my circuit:
#
# ![Swanky%20Gogo%281%29.png](attachment:Swanky%20Gogo%281%29.png)
#
# **Notes:**
# - For $V_{B}=4.7$ V ish, the signal starts to become unhindered around $V_{offset}=3.7$ V. Below this, the signal is more square or hump-like
# - The voltage difference between each of the channels is roughly $0.7$ V as predicted by the lab description.
# - It's helpful to use a higher frequency to capture the behavior of the signal over a longer period, like 1 kHz to 3 kHz
